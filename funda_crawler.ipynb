# %%
url_fund="https://www.funda.nl/huur/enschede/woonhuis/3+kamers/"

# %% [markdown]
# ### Other source of information
# - https://www.huurwoningen.nl
# - https://www.pararius.nl
# - https://www.huislijn.nl
# - https://directwonen.nl

# %%
import pandas as pd

import cfscrape
header = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9',
              'Accept-Encoding': 'gzip, deflate, sdch',
              'Accept-Language' : 'nl-NL,nl;q=0.8,en-US;q=0.6,en;q=0.4',
              'Cache-Control' : 'max-age=0',
              'Connection': 'keep-alive',
              'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.81 Safari/537.36'}

from lxml import etree
from bs4 import BeautifulSoup

import urllib
import re
from random import randint
from time import sleep

pd.set_option('display.max_colwidth', -1)

# %%
def get_links_funda_query(link):
    all_links=[]
    page=1
    raw_link = link
    
    while True:
        print("Scraping page",page)
        scraper = cfscrape.create_scraper()    
        scraped_html=scraper.get(link,headers=header).content.decode("utf-8") 
        parsed_html = BeautifulSoup(scraped_html)

        data = parsed_html.body.find_all('div', attrs={'class':'search-result-media'})
       
        if data:
            for div in data:
                links = div.findAll('a')
                for a in links:
                    all_links.append("https://www.funda.nl" + a['href'])

            if len(links)<1:
                break
            page=page+1
            link = raw_link+'p'+str(page)
        else:
            print("There is NO page",page,"!")
            break

    return all_links

# %%
links = get_links_funda_query(url_funda)
# https://www.funda.nl/huur/hengelo/0-1000/woonhuis/3+kamers/tuin/+15km/
# Out:
# Scraping page 1
# Scraping page 2
# There is NO page 2 !

# %%
links
# Out:
# ['https://www.funda.nl/huur/enschede/huis-40378461-steenbeltweg-15/',
#  'https://www.funda.nl/huur/enschede/huis-40315565-potsweg-98/',
#  'https://www.funda.nl/huur/enschede/huis-40378276-hj-van-heekplein-58-3/',
#  'https://www.funda.nl/huur/enschede/huis-40393654-talmaplein-14/',
#  'https://www.funda.nl/huur/enschede/huis-40211399-lasondersingel-11/',
#  'https://www.funda.nl/huur/enschede/huis-40205940-waterviolierlaan-1/',
#  'https://www.funda.nl/huur/enschede/huis-40104202-prinsestraat-12/',
#  'https://www.funda.nl/huur/enschede/huis-40315426-lindebrink-1/',
#  'https://www.funda.nluwarywuezqwsavyuuurxfsy.html',
#  'https://www.funda.nl/huur/enschede/huis-40208296-samarindastraat-6/',
#  'https://www.funda.nl/huur/enschede/huis-40208796-castorstraat-13/',
#  'https://www.funda.nl/huur/enschede/huis-40292884-uilvlinder-11/',
#  'https://www.funda.nl/huur/enschede/huis-40292880-floraparkstraat-19/',
#  'https://www.funda.nl/huur/enschede/huis-40218298-muldermanshoek-58/',
#  'https://www.funda.nl/huur/enschede/huis-40136219-hoge-bothofstraat-128/',
#  'https://www.funda.nl/huur/enschede/huurcomplex-49991834-eelenbrink-46-64-piksenbrink-30-36-radewijkbrink-1-31-striepebrink-19-37/?objecttypeId=4096761b-efd7-4bf6-9a21-6327097f7982']

# %%
def scrape_funda_single_page (url):
    scraper = cfscrape.create_scraper()
    
    scraped_html=scraper.get(url,headers=header).content
    print(scraped_html.decode("utf-8") )
    html = etree.HTML(scraped_html)
    
    description = html.xpath("//title/text()")[0].replace('Huis te huur: ','').replace(' [funda]','')
    # postal_code = re.search(r'\d{4} [A-Z]{2}', description).group(0)
    city = re.search(r'\d{4} [A-Z]{2} \w+',description).group(0).split()[2]
    # address = re.findall(r'(.*) \d{4}',description)[0]
    price = html.xpath("//strong[@class='object-header__price']/text()")[0].replace('€ ','').replace(' /mnd','').replace('.','')
    bouwjaar = html.xpath("//dl[@class='object-kenmerken-list']")[1].xpath("dd/text()")[2].replace('\r\n','')
    inhoud = html.xpath("//dl[@class='object-kenmerken-list']")[2].xpath("dd/text()")[1].replace('\r\n','')
    kamers = html.xpath("//dl[@class='object-kenmerken-list']")[3].xpath("dd/text()")[0].replace('\r\n','')
    woonlagen = html.xpath("//dl[@class='object-kenmerken-list']")[3].xpath("dd/text()")[1].replace('\r\n','')
    
    return pd.DataFrame({'description':description,
                         'city':city,
                         'price':price,
                         'bouwjaar': bouwjaar,
                         'inhoud':inhoud,
                         'kamers': kamers,
                         'woonlagen': woonlagen})

# %%
scrape_funda_single_page('https://www.funda.nl/huur/enschede/huis-40378461-steenbeltweg-15/')
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
# <META NAME="ROBOTS" CONTENT="NOINDEX, NOFOLLOW">
# <meta http-equiv="cache-control" content="max-age=0" />
# <meta http-equiv="cache-control" content="no-cache" />
# <meta http-equiv="expires" content="0" />
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />
# <meta http-equiv="pragma" content="no-cache" />
# <meta http-equiv="refresh" content="10; url=/distil_r_captcha.html?requestId=a486b74f-3109-4dbd-8da8-3af6d8403c7b&httpReferrer=%2Fhuur%2Fenschede%2Fhuis-40378461-steenbeltweg-15%2F" />
# <script type="text/javascript">
# 	(function(window){
# 		try {
# 			if (typeof sessionStorage !== 'undefined'){
# 				sessionStorage.setItem('distil_referrer', document.referrer);
# 			}
# 		} catch (e){}
# 	})(window);
# </script>
# <script type="text/javascript" src="/fundadst.ztfqaeubfvatyvtvvxeettebcztwestzu.js" defer></script><style type="text/css">#d__fFH{position:absolute;top:-5000px;left:-5000px}#d__fF{font-family:serif;font-size:200px;visibility:hidden}#wvxdeyes{display:none!important}</style></head>
# <body>
# <div id="distilIdentificationBlock">&nbsp;</div>
# </body>
# </html>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-dbc792f77625> in <module>()
# ----> 1 scrape_funda_single_page('https://www.funda.nl/huur/enschede/huis-40378461-steenbeltweg-15/')
#
# <ipython-input-103-f6d0c102749c> in scrape_funda_single_page(url)
#       6     html = etree.HTML(scraped_html)
#       7
# ----> 8     description = html.xpath("//title/text()")[0].replace('Huis te huur: ','').replace(' [funda]','')
#       9     # postal_code = re.search(r'\d{4} [A-Z]{2}', description).group(0)
#      10     city = re.search(r'\d{4} [A-Z]{2} \w+',description).group(0).split()[2]
#
# IndexError: list index out of range

# %%
description, postal_code,city,address, price,bouwjaar, inhoud,kamers, woonlagen
# Out:
# ('Potsweg 98 7523 LB Enschede',
#  '7523 LB',
#  'Enschede',
#  'Potsweg 98',
#  '926',
#  '1971-1980',
#  '350 m³',
#  '6 kamers (3 slaapkamers)',
#  '2 badkamers en 1 apart toilet')

# %%
###
#Concatenating all dataframes
df = pd.DataFrame()
for link in links:
    df_temp = scrape_funda_single_page(link)
    df = pd.concat([df,df_temp], axis=0, ignore_index=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Bike Distance from UT

# %%
import googlemaps
from datetime import datetime

def gmaps_bike_distance (key, point_a, point_b):
    gmaps = googlemaps.Client(key=key)
    directions_result = gmaps.directions(point_a, point_b, mode="bicycling")
    bike_distance = directions_result[0][u'legs'][0][u'distance'][u'text'].replace(' km','')
    return float(bike_distance)

def bike_distance_from_ut(point_b):
    return gmaps_bike_distance (google_key, 'University of Twente', point_b)

# %% [markdown]
# ## Enriching the distance from the house to UT

# %%
df['distance_ut'] = df['address'].map(lambda x: bike_distance_from_ut(x))

# %% [markdown]
# ## Displaying specific information

# %%
df[['link','distance_ut', 'Huurprijs ','Bouwjaar', 'Aantal kamers','Tuin']].sort_values(by=['distance_ut','Huurprijs '])
# Out:
#                                                                            link  \
# 12  https://www.funda.nl/huur/enschede/huis-40526049-hengelosestraat-138/
# 34  https://www.funda.nl/huur/hengelo/huis-40883295-hermesstraat-40/
# 15  https://www.funda.nl/huur/enschede/huis-40854757-ankrot-110/
# 29  https://www.funda.nl/huur/enschede/huis-40726524-roombeekstraat-60/
# 35  https://www.funda.nl/huur/enschede/huis-40884037-laaressingel-103/
# 3   https://www.funda.nl/huur/enschede/huis-40809158-sniedershorst-68/
# 27  https://www.funda.nl/huur/enschede/huis-40870907-vrugginklanden-12/
# 11  https://www.funda.nl/huur/hengelo/huis-40681224-tom-mandersstraat-3/
# 21  https://www.funda.nl/huur/enschede/huis-40870057-kalkerlanden-24/
# 0   https://www.funda.nl/huur/hengelo/huis-40898395-hammerfeststraat-25/
# 25  https://www.funda.nl/huur/borne/huis-40870980-tuinlaan-231/
# 33  https://www.funda.nl/huur/enschede/huis-40891118-heidevlinder-32/
# 26  https://www.funda.nl/huur/enschede/huis-40899285-heidevlinder-56/
# 14  https://www.funda.nl/huur/borne/huis-40870056-weerselosestraat-228/
# 28  https://www.funda.nl/huur/hengelo/huis-40878705-sluitersdijk/
# 5   https://www.funda.nl/huur/delden/huis-40873238-hassinkstraat-11/
# 1   https://www.funda.nl/huur/delden/huis-40895517-de-dinkel-27/
# 8   https://www.funda.nl/huur/losser/huis-86023479-arendstraat-4/
# 17  https://www.funda.nl/huur/oldenzaal/huis-86254819-erve-klopper-7/
# 32  https://www.funda.nl/huur/oldenzaal/huis-40866425-zevenblad-45/
# 20  https://www.funda.nl/huur/oldenzaal/huis-40759445-bereklauw-57/
# 13  https://www.funda.nl/huur/weerselo/huis-40893849-hilbertweg-2/
# 10  https://www.funda.nl/huur/almelo/huis-40808399-smaragdstraat-16/
# 2   https://www.funda.nl/huur/almelo/huis-40711154-singraven-88/
# 19  https://www.funda.nl/huur/almelo/huis-40664978-laan-van-indie-54/
# 7   https://www.funda.nl/huur/vriezenveen/huis-40600933-de-groenling-22/
# 30  https://www.funda.nl/huur/rijssen/huis-40602220-dennenlaan-95/
# 31  https://www.funda.nl/huur/rijssen/huis-40661920-dennenlaan-54/
# 18  https://www.funda.nl/huur/almelo/huis-86241041-beekstraat-67/
# 24  https://www.funda.nl/huur/hengelo/huis-40759639-tobias-asserstraat-4/
# 23  https://www.funda.nl/huur/haaksbergen/huis-40851852-paulus-potterstraat-30/
# 16  https://www.funda.nl/huur/hengelo/huis-40899871-valeriusstraat-3/
# 6   https://www.funda.nl/huur/haaksbergen/huis-40733145-beethovenstraat-87/
# 9   https://www.funda.nl/huur/oldenzaal/huis-40866614-zevenblad-61/
# 22  https://www.funda.nl/huur/almelo/huis-40883059-jan-van-goyenstraat-15/
# 4   https://www.funda.nl/huur/enschede/huis-40874045-kastanjestraat-3/
#
#     distance_ut                                             Huurprijs   \
# 12  2.7          € 995 per maand (geen servicekosten)
# 34  4.2          € 951 per maand (exclusief servicekosten à € 30 /mnd)
# 15  4.2          NaN
# 29  4.5          € 975 per maand (exclusief servicekosten à € 20 /mnd)
# 35  4.9          € 783 per maand (geen servicekosten)
# 3   5.8          € 985 per maand (geen servicekosten)
# 27  7.7          € 908 per maand (geen servicekosten)
# 11  7.8          € 830 per maand (geen servicekosten)
# 21  7.9          € 820 per maand (geen servicekosten)
# 0   9.4          € 850 per maand (geen servicekosten)
# 25  9.8          € 890 per maand (geen servicekosten)
# 33  10.5         € 887 per maand (inclusief servicekosten à € 10 /mnd)
# 26  10.6         € 914 per maand (inclusief servicekosten à € 10 /mnd)
# 14  11.1         € 870 per maand (geen servicekosten)
# 28  11.3         € 890 per maand (servicekosten onbekend)
# 5   11.6         € 972 per maand (exclusief servicekosten à € 30 /mnd)
# 1   11.8         NaN
# 8   13.3         € 850 per maand (geen servicekosten)
# 17  14.9         € 901 per maand (inclusief servicekosten à € 6 /mnd)
# 32  15.1         € 755 per maand (geen servicekosten)
# 20  15.2         € 735 per maand (geen servicekosten)
# 13  17.3         € 1.000 per maand (geen servicekosten)
# 10  18.9         € 795 per maand (geen servicekosten)
# 2   25.1         € 850 per maand (geen servicekosten)
# 19  25.4         € 991 per maand (exclusief servicekosten à € 20 /mnd)
# 7   27.3         € 715 per maand (geen servicekosten)
# 30  28.1         € 805 per maand (geen servicekosten)
# 31  28.3         € 805 per maand (geen servicekosten)
# 18  88.0         € 700 per maand (geen servicekosten)
# 24  158.0        € 895 per maand (servicekosten onbekend)
